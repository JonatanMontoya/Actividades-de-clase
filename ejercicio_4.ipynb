# %% [markdown]
# <a href="https://colab.research.google.com/github/JonatanMontoya/Actividades-de-clase/blob/main/ejercicio_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 4

# %%
#Montoya Lopez Jonatan Emmanuel
import random
import matplotlib.pyplot as plt 
import numpy as np 
import math
from statistics import mean, variance

def MC(n):
    pi = 0
    lx = []
    ly = []
    counter = 0
    xi = 0
    Z = []
    for i in range(n):
        x = random.random()
        y = random.random()
        if x**2 + y**2 <1:
            counter = counter + 1
            lx.append(counter)
            ly.append(4.0*float(counter)/(i + 1))
            xi = 1
            Z.append(xi)
        else:
            xi = 0
            Z.append(xi)
        pi = 4.0*float(counter)/(i + 1)
        e = np.absolute((pi - np.pi)/np.pi)
        
    p=np.pi/4

    prom = mean(Z)
    errorE = np.absolute((prom - (p))/(p)) 
    var = variance(Z)
    errorV = np.absolute((var - ((p)*(1-p)))/(p))
    print("PI =", pi)
    print("ERROR =", e)
    print("VALOR ESPERADO (SIMULACION)", prom)
    print("ERROR ESPERANZA", errorE)
    print("VARIANZA (SIMULACION)", var)
    print("ERROR VALOR REAL", errorV)
    
    fig = plt.figure(1, figsize=(10, 10))        
    plt.grid()
    plt.plot(lx, ly, color="blue", markersize=1)
    plt.show()

MC(80)
# Out:
# PI = 3.1
# ERROR = 0.013239352830248852
# VALOR ESPERADO (SIMULACION) 0.775
# ERROR ESPERANZA 0.013239352830248852
# VARIANZA (SIMULACION) 0.17658227848101266
# ERROR VALOR REAL 0.010229703258910568

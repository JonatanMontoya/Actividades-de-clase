# %% [markdown]
# <a href="https://colab.research.google.com/github/JonatanMontoya/Actividades-de-clase/blob/main/ejercicio_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 1:
#
# a)Usar la función random() para simular 1 volado.
#
# b)Usar la función random() para simular 1000 volados.
#
# c)Determinar de b) la probabilidad de que ocurra "sol" en un volado

# %%
#Montoya López Jonatan Emmanuel
# a)
import random
from collections import Counter

resultado = ['Cara', 'Cruz']
def selectRandom(resultado):
  return random.choice(resultado)

print("El volado arrojo: ",selectRandom(resultado))
print("")

# b)

for i in range(1000):
    seleccion=selectRandom(resultado)
    print(i+1, seleccion)

# c)
print("De probabilidad sabemos que la probabilidad de que ocurra sol es: ",1/2)
# Out:
# El volado arrojo:  Cruz
#
# 1 Cruz
# 2 Cara
# 3 Cruz
# 4 Cruz
# 5 Cruz
# 6 Cruz
# 7 Cara
# 8 Cara
# 9 Cruz
# 10 Cruz
# 11 Cruz
# 12 Cruz
# 13 Cara
# 14 Cara
# 15 Cara
# 16 Cruz
# 17 Cara
# 18 Cara
# 19 Cruz
# 20 Cruz
# 21 Cruz
# 22 Cara
# 23 Cruz
# 24 Cruz
# 25 Cruz
# 26 Cruz
# 27 Cara
# 28 Cruz
# 29 Cruz
# 30 Cara
# 31 Cruz
# 32 Cruz
# 33 Cruz
# 34 Cara
# 35 Cara
# 36 Cara
# 37 Cara
# 38 Cruz
# 39 Cara
# 40 Cruz
# 41 Cruz
# 42 Cruz
# 43 Cruz
# 44 Cruz
# 45 Cruz
# 46 Cara
# 47 Cara
# 48 Cara
# 49 Cara
# 50 Cruz
# 51 Cruz
# 52 Cruz
# 53 Cara
# 54 Cruz
# 55 Cara
# 56 Cruz
# 57 Cara
# 58 Cara
# 59 Cara
# 60 Cruz
# 61 Cruz
# 62 Cara
# 63 Cruz
# 64 Cara
# 65 Cruz
# 66 Cara
# 67 Cara
# 68 Cruz
# 69 Cara
# 70 Cara
# 71 Cara
# 72 Cara
# 73 Cruz
# 74 Cara
# 75 Cruz
# 76 Cruz
# 77 Cruz
# 78 Cara
# 79 Cara
# 80 Cara
# 81 Cruz
# 82 Cara
# 83 Cruz
# 84 Cruz
# 85 Cara
# 86 Cara
# 87 Cruz
# 88 Cara
# 89 Cruz
# 90 Cruz
# 91 Cruz
# 92 Cara
# 93 Cara
# 94 Cruz
# 95 Cruz
# 96 Cara
# 97 Cara
# 98 Cara
# ...
